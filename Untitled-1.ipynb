# %%
# Importar librerías
import cv2
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import matplotlib.image as imread

from pca import pca
from sklearn.cluster import DBSCAN
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
img_filename = '2_Cleaned_dataset/images/Adult_11.png'
image = cv2.imread(img_filename)
print(image.shape)
plt.imshow(image)
# Out:
# (188, 398, 3)

# %%
def cut_image(image, coords, show=False, saveToFile=None):
    caption = image[coords[1]:coords[1] + coords[3], coords[0]:coords[0] + coords[2]]

    if show:
        plt.imshow(caption, cmap='gray')

    if saveToFile:
        cv2.imwrite(saveToFile, caption)

    return caption

caption = cut_image(image, coords=(80, 40, 260, 100), show=True, saveToFile="imagen_recortada.jpg")

# %%
X = image.reshape(-1, 1)
X.shape
# Out:
# (224472, 1)

# %%
f"Tipo: {type(X)} - Dimensiones: {X.ndim} - Longitud: {len(X)} - Longitud dim 0: {len(X[0])} - Longitud dim 1: {len(X[1])}"
# Out:
# "Tipo: <class 'numpy.ndarray'> - Dimensiones: 2 - Longitud: 224472 - Longitud dim 0: 1 - Longitud dim 1: 1"

# %%
dbscan = DBSCAN(eps=0.002, min_samples=500, metric='cosine')
dbscan.fit(X)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Untitled-1.ipynb Cell 5 line 2
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=0'>1</a> dbscan = DBSCAN(eps=0.002, min_samples=500, metric='cosine')
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W1sdW50aXRsZWQ%3D?line=1'>2</a> dbscan.fit(X)
#
# File c:\anaconda3\envs\NoSupervisado\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File c:\anaconda3\envs\NoSupervisado\lib\site-packages\sklearn\cluster\_dbscan.py:396, in DBSCAN.fit(self, X, y, sample_weight)
#     394 neighbors_model.fit(X)
#     395 # This has worst case O(n^2) memory complexity
# --> 396 neighborhoods = neighbors_model.radius_neighbors(X, return_distance=False)
#     398 if sample_weight is None:
#     399     n_neighbors = np.array([len(neighbors) for neighbors in neighborhoods])
#
# File c:\anaconda3\envs\NoSupervisado\lib\site-packages\sklearn\neighbors\_base.py:1215, in RadiusNeighborsMixin.radius_neighbors(self, X, radius, return_distance, sort_results)
#    1213     results = neigh_dist, neigh_ind
#    1214 else:
# -> 1215     neigh_ind_list = sum(chunked_results, [])
#    1216     results = _to_object_array(neigh_ind_list)
#    1218 if sort_results:
#
# File c:\anaconda3\envs\NoSupervisado\lib\site-packages\sklearn\metrics\pairwise.py:2026, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    2024 if reduce_func is not None:
#    2025     chunk_size = D_chunk.shape[0]
# -> 2026     D_chunk = reduce_func(D_chunk, sl.start)
#    2027     _check_chunk_size(D_chunk, chunk_size)
#    2028 yield D_chunk
#
# File c:\anaconda3\envs\NoSupervisado\lib\site-packages\sklearn\neighbors\_base.py:1046, in RadiusNeighborsMixin._radius_neighbors_reduce_func(self, dist, start, radius, return_distance)
#    1019 def _radius_neighbors_reduce_func(self, dist, start, radius, return_distance):
#    1020     """Reduce a chunk of distances to the nearest neighbors.
#    1021
#    1022     Callback to :func:`sklearn.metrics.pairwise.pairwise_distances_chunked`
#    (...)
#    1044         The neighbors indices.
#    1045     """
# -> 1046     neigh_ind = [np.where(d <= radius)[0] for d in dist]
#    1048     if return_distance:
#    1049         if self.effective_metric_ == "euclidean":
#
# File c:\anaconda3\envs\NoSupervisado\lib\site-packages\sklearn\neighbors\_base.py:1046, in <listcomp>(.0)
#    1019 def _radius_neighbors_reduce_func(self, dist, start, radius, return_distance):
#    1020     """Reduce a chunk of distances to the nearest neighbors.
#    1021
#    1022     Callback to :func:`sklearn.metrics.pairwise.pairwise_distances_chunked`
#    (...)
#    1044         The neighbors indices.
#    1045     """
# -> 1046     neigh_ind = [np.where(d <= radius)[0] for d in dist]
#    1048     if return_distance:
#    1049         if self.effective_metric_ == "euclidean":
#
# File <__array_function__ internals>:200, in where(*args, **kwargs)
#
# MemoryError: Unable to allocate 1.57 MiB for an array with shape (206286, 1) and data type int64

# %%
df = pd.read_hdf('2_Cleaned_dataset/images.h5', key='data')
df.shape
# Out:
# (910, 11)

# %%
sample = df[df['file_name'] == 'Adult_11.png']
sample
# Out:
#                                 full_path main_folder intermediate_path  \
# 12  2_Cleaned_dataset\images\Adult_11.png      images            images
#
#        file_name category format  height  width   size  bands  \
# 12  Adult_11.png    Adult    PNG     188    398  35843      1
#
#                                                 image
# 12  [[174, 163, 156, 151, 150, 142, 143, 142, 143,...

# %%
# Aplanamos las imágenes antes de crear una matriz de valores estandarizados
X = np.stack(df['image'].apply(lambda x: x.flatten()))
scaler = StandardScaler()
X_standardized = scaler.fit_transform(X)

# Crea un DataFrame a partir de los datos escalados
X_standardized_df = pd.DataFrame(X_standardized)

pca_model = PCA(n_components=300)
pca_model.fit(X_standardized_df)
X_reduced = pca_model.transform(X_standardized_df)

# %%
X_reduced.shape
# Out:
# (910, 300)

# %%
sample_image = pca_model.inverse_transform([X_reduced[12]])

# %%
sample_image.shape
# Out:
# (1, 74824)

# %%
plt.imshow(sample_image.reshape((188, 398)), cmap='gray')

# %%
X2 = df_images[11:12]
f"Tipo: {type(X)} - Dimensiones: {X2.ndim} - Longitud: {len(X2)} - Longitud dim 0: {len(X2[0])}"
# Out:
# "Tipo: <class 'numpy.ndarray'> - Dimensiones: 2 - Longitud: 1 - Longitud dim 0: 700"

# %%
X3 = df_images[11:12].ravel()
f"Tipo: {type(X3)} - Dimensiones: {X3.ndim} - Longitud: {len(X3)}"
# Out:
# "Tipo: <class 'numpy.ndarray'> - Dimensiones: 1 - Longitud: 700"

# %%
X4 = sample_image.reshape(-1, 1)
f"Tipo: {type(X4)} - Dimensiones: {X4.ndim} - Longitud: {len(X4)} - Longitud dim 0: {len(X4[0])} - Longitud dim 1: {len(X4[1])}"
# Out:
# "Tipo: <class 'numpy.ndarray'> - Dimensiones: 2 - Longitud: 74824 - Longitud dim 0: 1 - Longitud dim 1: 1"

# %%
caption4 = cut_image(sample_image.reshape((188, 398)), coords=(80, 40, 260, 100), show=True)

# %%
X4_ = caption4.reshape(-1, 1)
f"Tipo: {type(X4_)} - Dimensiones: {X4_.ndim} - Longitud: {len(X4_)} - Longitud dim 0: {len(X4_[0])} - Longitud dim 1: {len(X4_[1])}"
# Out:
# "Tipo: <class 'numpy.ndarray'> - Dimensiones: 2 - Longitud: 26000 - Longitud dim 0: 1 - Longitud dim 1: 1"

# %%
dbscan4 = DBSCAN(eps=0.002, min_samples=50, metric='euclidean', n_jobs=-1)
dbscan4.fit(X4_)
unique_labels = np.unique(dbscan4.labels_)
unique_labels
# Out:
# array([-1,  0,  1,  2,  3,  4], dtype=int64)

# %%
# Obtener las coordenadas de los pixeles que pertenecen a cada cluster
for label in unique_labels:
    if label == -1:
        # Ignorar los puntos ruidosos
        continue
    # Crear una máscara booleana para los puntos que pertenecen al cluster actual
    mask = dbscan4.labels_ == label
    # Obtener las coordenadas de los puntos que pertenecen al cluster actual
    coords = np.argwhere(mask)
    # Resaltar los puntos en la imagen original
    caption4[coords[:, 0], coords[:, 1]] = [255, 0, 0]  # Rojo brillante
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\user\Documents\Uniandes\DentalSegmentation\Untitled-1.ipynb Cell 20 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/Uniandes/DentalSegmentation/Untitled-1.ipynb#X32sZmlsZQ%3D%3D?line=8'>9</a> coords = np.argwhere(mask)
#      <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/Uniandes/DentalSegmentation/Untitled-1.ipynb#X32sZmlsZQ%3D%3D?line=9'>10</a> # Resaltar los puntos en la imagen original
# ---> <a href='vscode-notebook-cell:/c%3A/Users/user/Documents/Uniandes/DentalSegmentation/Untitled-1.ipynb#X32sZmlsZQ%3D%3D?line=10'>11</a> caption4[coords[:, 0], coords[:, 1]] = [255, 0, 0]  # Rojo brillante
#
# IndexError: index 1 is out of bounds for axis 1 with size 1

# %%
len(np.argwhere(dbscan4.labels_ == 0))
# Out:
# 25861
